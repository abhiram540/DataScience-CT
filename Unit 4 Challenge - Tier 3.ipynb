# %% [markdown]
# # Springboard Data Science Career Track Unit 4 Challenge - Tier 3 Complete
#
# ## Objectives
# Hey! Great job getting through those challenging DataCamp courses. You're learning a lot in a short span of time.
#
# In this notebook, you're going to apply the skills you've been learning, bridging the gap between the controlled environment of DataCamp and the *slightly* messier work that data scientists do with actual datasets!
#
# Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***
#
#
# A borough is just a fancy word for district. You may be familiar with the five boroughs of New York… well, there are 32 boroughs within Greater London [(here's some info for the curious)](https://en.wikipedia.org/wiki/London_boroughs). Some of them are more desirable areas to live in, and the data will reflect that with a greater rise in housing prices.
#
# ***This is the Tier 3 notebook, which means it's not filled in at all: we'll just give you the skeleton of a project, the brief and the data. It's up to you to play around with it and see what you can find out! Good luck! If you struggle, feel free to look at easier tiers for help; but try to dip in and out of them, as the more independent work you do, the better it is for your learning!***
#
# This challenge will make use of only what you learned in the following DataCamp courses:
# - Prework courses (Introduction to Python for Data Science, Intermediate Python for Data Science)
# - Data Types for Data Science
# - Python Data Science Toolbox (Part One)
# - pandas Foundations
# - Manipulating DataFrames with pandas
# - Merging DataFrames with pandas
#
# Of the tools, techniques and concepts in the above DataCamp courses, this challenge should require the application of the following:
# - **pandas**
#     - **data ingestion and inspection** (pandas Foundations, Module One)
#     - **exploratory data analysis** (pandas Foundations, Module Two)
#     - **tidying and cleaning** (Manipulating DataFrames with pandas, Module Three)
#     - **transforming DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **subsetting DataFrames with lists** (Manipulating DataFrames with pandas, Module One)
#     - **filtering DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **grouping data** (Manipulating DataFrames with pandas, Module Four)
#     - **melting data** (Manipulating DataFrames with pandas, Module Three)
#     - **advanced indexing** (Manipulating DataFrames with pandas, Module Four)
# - **matplotlib** (Intermediate Python for Data Science, Module One)
# - **fundamental data types** (Data Types for Data Science, Module One)
# - **dictionaries** (Intermediate Python for Data Science, Module Two)
# - **handling dates and times** (Data Types for Data Science, Module Four)
# - **function definition** (Python Data Science Toolbox - Part One, Module One)
# - **default arguments, variable length, and scope** (Python Data Science Toolbox - Part One, Module Two)
# - **lambda functions and error handling** (Python Data Science Toolbox - Part One, Module Four)

# %% [markdown]
# ## The Data Science Pipeline
#
# This is Tier Three, so we'll get you started. But after that, it's all in your hands! When you feel done with your investigations, look back over what you've accomplished, and prepare a quick presentation of your findings for the next mentor meeting.
#
# Data Science is magical. In this case study, you'll get to apply some complex machine learning algorithms. But as  [David Spiegelhalter](https://www.youtube.com/watch?v=oUs1uvsz0Ok) reminds us, there is no substitute for simply **taking a really, really good look at the data.** Sometimes, this is all we need to answer our question.
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
# 1. Sourcing and loading
# 2. Cleaning, transforming, and visualizing
# 3. Modeling
# 4. Evaluating and concluding

# %% [markdown]
# ### 1. Sourcing and Loading
#
# Any Data Science project kicks off by importing  ***pandas***. The documentation of this wonderful library can be found [here](https://pandas.pydata.org/). As you've seen, pandas is conveniently connected to the [Numpy](http://www.numpy.org/) and [Matplotlib](https://matplotlib.org/) libraries.
#
# ***Hint:*** This part of the data science pipeline will test those skills you acquired in the pandas Foundations course, Module One.

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
# Let's import the pandas, numpy libraries as pd, and np respectively. 
import pandas as pd
import numpy as np

# Load the pyplot collection of functions from matplotlib, as plt 
from matplotlib import pyplot as plt
from datetime import datetime

# %% [markdown]
# #### 1.2.  Loading the data
# Your data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %%
# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls

url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file. 
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.  
properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= None)

# %% [markdown]
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.
#
# Keep the end goal in mind as you move through this process, every step will take you closer.
#
#
#
# ***Hint:*** This part of the data science pipeline should test those skills you acquired in:
# - Intermediate Python for data science, all modules.
# - pandas Foundations, all modules.
# - Manipulating DataFrames with pandas, all modules.
# - Data Types for Data Science, Module Four.
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# **2.1. Exploring your data**
#
# Think about your pandas functions for checking out a dataframe.

# %%
#type(properties)
#properties.info()
#print(properties)
properties.head()
# Out:
#   Unnamed: 0 City of London Barking & Dagenham     Barnet     Bexley  \
# 0        NaT      E09000001          E09000002  E09000003  E09000004
# 1 1995-01-01          91449            50460.2    93284.5    64958.1
# 2 1995-02-01        82202.8            51085.8    93190.2    64787.9
# 3 1995-03-01        79120.7              51269    92247.5    64367.5
# 4 1995-04-01        77101.2            53133.5    90762.9    64277.7
#
#        Brent    Bromley     Camden    Croydon     Ealing  ... NORTH WEST  \
# 0  E09000005  E09000006  E09000007  E09000008  E09000009  ...  E12000002
# 1    71306.6    81671.5     120933    69158.2    79885.9  ...    43958.5
# 2    72022.3    81657.6     119509    68951.1    80897.1  ...    43925.4
# 3    72015.8    81449.3     120282    68712.4    81379.9  ...    44434.9
# 4    72965.6    81124.4     120098      68610    82188.9  ...    44267.8
#
#   YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND     LONDON  \
# 0          E12000003     E12000004     E12000005       E12000006  E12000007
# 1            44803.4       45544.5       48527.5         56701.6    74435.8
# 2            44528.8       46051.6       49341.3         56593.6    72777.9
# 3            45200.5       45383.8       49442.2         56171.2    73896.8
# 4            45614.3       46124.2       49455.9         56567.9    74455.3
#
#   SOUTH EAST SOUTH WEST Unnamed: 47    England
# 0  E12000008  E12000009         NaN  E92000001
# 1    64018.9    54705.2         NaN    53202.8
# 2      63715    54356.1         NaN    53096.2
# 3    64113.6    53583.1         NaN    53201.3
# 4    64623.2      54786         NaN    53590.9
#
# [5 rows x 49 columns]

# %% [markdown]
# **2.2. Cleaning the data**
#
# You might find you need to transpose your dataframe, check out what its row indexes are, and reset the index. You  also might find you need to assign the values of the first row to your column headings  . (Hint: recall the .columns feature of DataFrames, as well as the iloc[] method).
#
# Don't be afraid to use StackOverflow for help  with this.

# %%
properties_transposed = properties.transpose().reset_index()
properties_transposed.head()
# Out:
#                 index          0                    1                    2  \
# 0          Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1      City of London  E09000001                91449              82202.8
# 2  Barking & Dagenham  E09000002              50460.2              51085.8
# 3              Barnet  E09000003              93284.5              93190.2
# 4              Bexley  E09000004              64958.1              64787.9
#
#                      3                    4                    5  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1              79120.7              77101.2              84409.1
# 2                51269              53133.5              53042.2
# 3              92247.5              90762.9                90258
# 4              64367.5              64277.7              63997.1
#
#                      6                    7                    8  ...  \
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...
# 1              94900.5               110128               112329  ...
# 2              53700.3              52113.1              52232.2  ...
# 3              90107.2              91441.2              92361.3  ...
# 4              64252.3              63722.7              64432.6  ...
#
#                    296                  297                  298  \
# 0  2019-08-01 00:00:00  2019-09-01 00:00:00  2019-10-01 00:00:00
# 1               813770               810455               826227
# 2               299421               304778               304579
# 3               528577               526670               525678
# 4               337523               333340               332920
#
#                    299                  300                  301  \
# 0  2019-11-01 00:00:00  2019-12-01 00:00:00  2020-01-01 00:00:00
# 1               776894               737275               747611
# 2               306390               301283               303653
# 3               522639               519306               518542
# 4               333657               336302               334765
#
#                    302                  303                  304  \
# 0  2020-02-01 00:00:00  2020-03-01 00:00:00  2020-04-01 00:00:00
# 1               777640               844989               867841
# 2               304265               304099               283139
# 3               519121               527747               526553
# 4               337760               339215               346840
#
#                    305
# 0  2020-05-01 00:00:00
# 1               899831
# 2               295744
# 3               532503
# 4               339408
#
# [5 rows x 307 columns]

# %%
properties_transposed.columns = properties_transposed.iloc[0]
properties_transposed.head()
# Out:
# 0          Unnamed: 0        NaN  1995-01-01 00:00:00  1995-02-01 00:00:00  \
# 0          Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1      City of London  E09000001                91449              82202.8
# 2  Barking & Dagenham  E09000002              50460.2              51085.8
# 3              Barnet  E09000003              93284.5              93190.2
# 4              Bexley  E09000004              64958.1              64787.9
#
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1              79120.7              77101.2              84409.1
# 2                51269              53133.5              53042.2
# 3              92247.5              90762.9                90258
# 4              64367.5              64277.7              63997.1
#
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...  \
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...
# 1              94900.5               110128               112329  ...
# 2              53700.3              52113.1              52232.2  ...
# 3              90107.2              91441.2              92361.3  ...
# 4              64252.3              63722.7              64432.6  ...
#
# 0  2019-08-01 00:00:00  2019-09-01 00:00:00  2019-10-01 00:00:00  \
# 0  2019-08-01 00:00:00  2019-09-01 00:00:00  2019-10-01 00:00:00
# 1               813770               810455               826227
# 2               299421               304778               304579
# 3               528577               526670               525678
# 4               337523               333340               332920
#
# 0  2019-11-01 00:00:00  2019-12-01 00:00:00  2020-01-01 00:00:00  \
# 0  2019-11-01 00:00:00  2019-12-01 00:00:00  2020-01-01 00:00:00
# 1               776894               737275               747611
# 2               306390               301283               303653
# 3               522639               519306               518542
# 4               333657               336302               334765
#
# 0  2020-02-01 00:00:00  2020-03-01 00:00:00  2020-04-01 00:00:00  \
# 0  2020-02-01 00:00:00  2020-03-01 00:00:00  2020-04-01 00:00:00
# 1               777640               844989               867841
# 2               304265               304099               283139
# 3               519121               527747               526553
# 4               337760               339215               346840
#
# 0  2020-05-01 00:00:00
# 0  2020-05-01 00:00:00
# 1               899831
# 2               295744
# 3               532503
# 4               339408
#
# [5 rows x 307 columns]

# %%
properties_cleaned1 = properties_transposed.drop(index=0, inplace=False)
properties_cleaned1.head()
# Out:
# 0          Unnamed: 0        NaN 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1      City of London  E09000001               91449             82202.8
# 2  Barking & Dagenham  E09000002             50460.2             51085.8
# 3              Barnet  E09000003             93284.5             93190.2
# 4              Bexley  E09000004             64958.1             64787.9
# 5               Brent  E09000005             71306.6             72022.3
#
# 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1             79120.7             77101.2             84409.1
# 2               51269             53133.5             53042.2
# 3             92247.5             90762.9               90258
# 4             64367.5             64277.7             63997.1
# 5             72015.8             72965.6               73704
#
# 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 1             94900.5              110128              112329  ...
# 2             53700.3             52113.1             52232.2  ...
# 3             90107.2             91441.2             92361.3  ...
# 4             64252.3             63722.7             64432.6  ...
# 5             74310.5               74127               73547  ...
#
# 0 2019-08-01 00:00:00 2019-09-01 00:00:00 2019-10-01 00:00:00  \
# 1              813770              810455              826227
# 2              299421              304778              304579
# 3              528577              526670              525678
# 4              337523              333340              332920
# 5              488784              501533              494770
#
# 0 2019-11-01 00:00:00 2019-12-01 00:00:00 2020-01-01 00:00:00  \
# 1              776894              737275              747611
# 2              306390              301283              303653
# 3              522639              519306              518542
# 4              333657              336302              334765
# 5              432188              427126              423161
#
# 0 2020-02-01 00:00:00 2020-03-01 00:00:00 2020-04-01 00:00:00  \
# 1              777640              844989              867841
# 2              304265              304099              283139
# 3              519121              527747              526553
# 4              337760              339215              346840
# 5              467145              461398              494455
#
# 0 2020-05-01 00:00:00
# 1              899831
# 2              295744
# 3              532503
# 4              339408
# 5              466574
#
# [5 rows x 307 columns]

# %% [markdown]
# **2.3. Cleaning the data (part 2)**
#
# You might we have to **rename** a couple columns. How do you do this? The clue's pretty bold...

# %%
properties_cleaned1.rename(columns={'Unnamed: 0':'London Borough', pd.NaT:'LB ID'}, inplace=True)
properties_cleaned1.index.names = ['index']
properties_cleaned1.head()
# Out:
# 0          London Borough      LB ID 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# index
# 1          City of London  E09000001               91449             82202.8
# 2      Barking & Dagenham  E09000002             50460.2             51085.8
# 3                  Barnet  E09000003             93284.5             93190.2
# 4                  Bexley  E09000004             64958.1             64787.9
# 5                   Brent  E09000005             71306.6             72022.3
#
# 0     1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# index
# 1                 79120.7             77101.2             84409.1
# 2                   51269             53133.5             53042.2
# 3                 92247.5             90762.9               90258
# 4                 64367.5             64277.7             63997.1
# 5                 72015.8             72965.6               73704
#
# 0     1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# index                                                              ...
# 1                 94900.5              110128              112329  ...
# 2                 53700.3             52113.1             52232.2  ...
# 3                 90107.2             91441.2             92361.3  ...
# 4                 64252.3             63722.7             64432.6  ...
# 5                 74310.5               74127               73547  ...
#
# 0     2019-08-01 00:00:00 2019-09-01 00:00:00 2019-10-01 00:00:00  \
# index
# 1                  813770              810455              826227
# 2                  299421              304778              304579
# 3                  528577              526670              525678
# 4                  337523              333340              332920
# 5                  488784              501533              494770
#
# 0     2019-11-01 00:00:00 2019-12-01 00:00:00 2020-01-01 00:00:00  \
# index
# 1                  776894              737275              747611
# 2                  306390              301283              303653
# 3                  522639              519306              518542
# 4                  333657              336302              334765
# 5                  432188              427126              423161
#
# 0     2020-02-01 00:00:00 2020-03-01 00:00:00 2020-04-01 00:00:00  \
# index
# 1                  777640              844989              867841
# 2                  304265              304099              283139
# 3                  519121              527747              526553
# 4                  337760              339215              346840
# 5                  467145              461398              494455
#
# 0     2020-05-01 00:00:00
# index
# 1                  899831
# 2                  295744
# 3                  532503
# 4                  339408
# 5                  466574
#
# [5 rows x 307 columns]

# %%
properties_cleaned1.columns
# Out:
# Index([   'London Borough',             'LB ID', 1995-01-01 00:00:00,
#        1995-02-01 00:00:00, 1995-03-01 00:00:00, 1995-04-01 00:00:00,
#        1995-05-01 00:00:00, 1995-06-01 00:00:00, 1995-07-01 00:00:00,
#        1995-08-01 00:00:00,
#        ...
#        2019-08-01 00:00:00, 2019-09-01 00:00:00, 2019-10-01 00:00:00,
#        2019-11-01 00:00:00, 2019-12-01 00:00:00, 2020-01-01 00:00:00,
#        2020-02-01 00:00:00, 2020-03-01 00:00:00, 2020-04-01 00:00:00,
#        2020-05-01 00:00:00],
#       dtype='object', name=0, length=307)

# %% [markdown]
# **2.4.Transforming the data**
#
# Remember what Wes McKinney said about tidy data?
#
# You might need to **melt** your DataFrame here.

# %%
Properties_Transformed = pd.melt(properties_cleaned1, id_vars=['London Borough', 'LB ID'], var_name='Date', value_name='AveragePrice')

# %%
Properties_Transformed
# Out:
#            London Borough      LB ID       Date AveragePrice
# 0          City of London  E09000001 1995-01-01        91449
# 1      Barking & Dagenham  E09000002 1995-01-01      50460.2
# 2                  Barnet  E09000003 1995-01-01      93284.5
# 3                  Bexley  E09000004 1995-01-01      64958.1
# 4                   Brent  E09000005 1995-01-01      71306.6
# ...                   ...        ...        ...          ...
# 14635              LONDON  E12000007 2020-05-01       479018
# 14636          SOUTH EAST  E12000008 2020-05-01       324659
# 14637          SOUTH WEST  E12000009 2020-05-01       261006
# 14638         Unnamed: 47        NaN 2020-05-01          NaN
# 14639             England  E92000001 2020-05-01       251973
#
# [14640 rows x 4 columns]

# %% [markdown]
# Remember to make sure your column data types are all correct. Average prices, for example, should be floating point numbers...

# %%
Properties_Transformed.dtypes
# Out:
# London Borough            object
# LB ID                     object
# Date              datetime64[ns]
# AveragePrice              object
# dtype: object

# %%
Properties_Transformed['AveragePrice'].dtypes
# Out:
# dtype('O')

# %%
#weather["Temp"] = weather.Temp.astype(float)
Properties_Transformed['AveragePrice'] = Properties_Transformed.AveragePrice.astype(float)

# %%
Properties_Transformed['AveragePrice'].dtypes
Properties_Transformed.dtypes
# Out:
# London Borough            object
# LB ID                     object
# Date              datetime64[ns]
# AveragePrice             float64
# dtype: object

# %% [markdown]
# **2.5. Cleaning the data (part 3)**
#
# Do we have an equal number of observations in the ID, Average Price, Month, and London Borough columns? Remember that there are only 32 London Boroughs. How many entries do you have in that column?
#
# Check out the contents of the London Borough column, and if you find null values, get rid of them however you see fit.

# %%
Properties_Transformed.count()
# Out:
# London Borough    14640
# LB ID             13725
# Date              14640
# AveragePrice      13725
# dtype: int64

# %% [markdown]
# ##### Observation
# Count of LB ID and AveragePrice columns is less than that of Borough and Date columns respectively. So we don't have equal number of observations in all the columns.

# %%
#print(clean_properties['AveragePrice'].isna() == True)
print(len(Properties_Transformed['London Borough'].unique()))
# Out:
# 48

# %%
Properties_Transformed['London Borough'].unique()
# Out:
# array(['City of London', 'Barking & Dagenham', 'Barnet', 'Bexley',
#        'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey',
#        'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth',
#        'Lewisham', 'Merton', 'Newham', 'Redbridge',
#        'Richmond upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets',
#        'Waltham Forest', 'Wandsworth', 'Westminster', 'Unnamed: 34',
#        'Inner London', 'Outer London', 'Unnamed: 37', 'NORTH EAST',
#        'NORTH WEST', 'YORKS & THE HUMBER', 'EAST MIDLANDS',
#        'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST',
#        'SOUTH WEST', 'Unnamed: 47', 'England'], dtype=object)

# %%
Properties_Transformed[Properties_Transformed['London Borough'] == 'Unnamed: 34']
# Out:
#       London Borough LB ID       Date  AveragePrice
# 33       Unnamed: 34   NaN 1995-01-01           NaN
# 81       Unnamed: 34   NaN 1995-02-01           NaN
# 129      Unnamed: 34   NaN 1995-03-01           NaN
# 177      Unnamed: 34   NaN 1995-04-01           NaN
# 225      Unnamed: 34   NaN 1995-05-01           NaN
# ...              ...   ...        ...           ...
# 14433    Unnamed: 34   NaN 2020-01-01           NaN
# 14481    Unnamed: 34   NaN 2020-02-01           NaN
# 14529    Unnamed: 34   NaN 2020-03-01           NaN
# 14577    Unnamed: 34   NaN 2020-04-01           NaN
# 14625    Unnamed: 34   NaN 2020-05-01           NaN
#
# [305 rows x 4 columns]

# %%
Properties_Transformed[Properties_Transformed['London Borough'] == 'Unnamed: 37']
# Out:
#       London Borough LB ID       Date  AveragePrice
# 36       Unnamed: 37   NaN 1995-01-01           NaN
# 84       Unnamed: 37   NaN 1995-02-01           NaN
# 132      Unnamed: 37   NaN 1995-03-01           NaN
# 180      Unnamed: 37   NaN 1995-04-01           NaN
# 228      Unnamed: 37   NaN 1995-05-01           NaN
# ...              ...   ...        ...           ...
# 14436    Unnamed: 37   NaN 2020-01-01           NaN
# 14484    Unnamed: 37   NaN 2020-02-01           NaN
# 14532    Unnamed: 37   NaN 2020-03-01           NaN
# 14580    Unnamed: 37   NaN 2020-04-01           NaN
# 14628    Unnamed: 37   NaN 2020-05-01           NaN
#
# [305 rows x 4 columns]

# %%
Properties_Transformed[Properties_Transformed['London Borough'] == 'Unnamed: 47']
# Out:
#       London Borough LB ID       Date  AveragePrice
# 46       Unnamed: 47   NaN 1995-01-01           NaN
# 94       Unnamed: 47   NaN 1995-02-01           NaN
# 142      Unnamed: 47   NaN 1995-03-01           NaN
# 190      Unnamed: 47   NaN 1995-04-01           NaN
# 238      Unnamed: 47   NaN 1995-05-01           NaN
# ...              ...   ...        ...           ...
# 14446    Unnamed: 47   NaN 2020-01-01           NaN
# 14494    Unnamed: 47   NaN 2020-02-01           NaN
# 14542    Unnamed: 47   NaN 2020-03-01           NaN
# 14590    Unnamed: 47   NaN 2020-04-01           NaN
# 14638    Unnamed: 47   NaN 2020-05-01           NaN
#
# [305 rows x 4 columns]

# %% [markdown]
# Here, I am deleting rows with London Borough having values 'Unnamed: 34', 'Unnamed: 37' and 'Unnamed: 47' because these Borough names doesn't make any sense to me and they don't have any values stored under 'LB ID' and 'AveragePrice' columns.

# %%
x = Properties_Transformed['London Borough']
Properties_Transformed = Properties_Transformed[(x != 'Unnamed: 34') & (x != 'Unnamed: 37') & (x != 'Unnamed: 47')]

# %%
Properties_Transformed['London Borough'].unique()
# Out:
# array(['City of London', 'Barking & Dagenham', 'Barnet', 'Bexley',
#        'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey',
#        'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth',
#        'Lewisham', 'Merton', 'Newham', 'Redbridge',
#        'Richmond upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets',
#        'Waltham Forest', 'Wandsworth', 'Westminster', 'Inner London',
#        'Outer London', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER',
#        'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON',
#        'SOUTH EAST', 'SOUTH WEST', 'England'], dtype=object)

# %%
Properties_Transformed.count()
# Out:
# London Borough    13725
# LB ID             13725
# Date              13725
# AveragePrice      13725
# dtype: int64

# %%
len(Properties_Transformed['London Borough'].unique())
# Out:
# 45

# %% [markdown]
# As you can see above that the number of unique Boroughs listed in the dataframe are 45, whereas there are only 33 Boroughs in Greater London including the City of London (Based on Wikipedia). Hence, we need to filter out all the extra Boroughs from the list to match up with the actual number 33.

# %%
nonBoroughs = ['NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER', 'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST', 'SOUTH WEST', 'England']
ActualBoroughs = ['City of London', 'City of Westminster',
    'Kensington and Chelsea',
    'Hammersmith and Fulham',
    'Wandsworth',
    'Lambeth',
    'Southwark',
    'Tower Hamlets',
    'Hackney',
    'Islington',
    'Camden',
    'Brent',
    'Ealing',
    'Hounslow',
    'Richmond upon Thames',
    'Kingston upon Thames',
    'Merton',
    'Sutton',
    'Croydon',
    'Bromley',
    'Lewisham',
    'Greenwich',
    'Bexley',
    'Havering',
    'Barking and Dagenham',
    'Redbridge',
    'Newham',
    'Waltham Forest',
    'Haringey',
    'Enfield',
    'Barnet',
    'Harrow',
    'Hillingdon',
]

# %%
Properties_Filtered = Properties_Transformed[~Properties_Transformed['London Borough'].isin(nonBoroughs)]
Properties_Filtered
# Out:
#            London Borough      LB ID       Date  AveragePrice
# 0          City of London  E09000001 1995-01-01   91448.98487
# 1      Barking & Dagenham  E09000002 1995-01-01   50460.22660
# 2                  Barnet  E09000003 1995-01-01   93284.51832
# 3                  Bexley  E09000004 1995-01-01   64958.09036
# 4                   Brent  E09000005 1995-01-01   71306.56698
# ...                   ...        ...        ...           ...
# 14622      Waltham Forest  E09000031 2020-05-01  443509.79640
# 14623          Wandsworth  E09000032 2020-05-01  615207.17390
# 14624         Westminster  E09000033 2020-05-01  937356.00420
# 14626        Inner London  E13000001 2020-05-01  592328.36820
# 14627        Outer London  E13000002 2020-05-01  427977.82440
#
# [10675 rows x 4 columns]

# %%
#df.isnull().values.any()
Prop_NullFilter = Properties_Filtered[Properties_Filtered['AveragePrice'].notna()]
Prop_NullFilter.head(5)
# Out:
#        London Borough      LB ID       Date  AveragePrice
# 0      City of London  E09000001 1995-01-01   91448.98487
# 1  Barking & Dagenham  E09000002 1995-01-01   50460.22660
# 2              Barnet  E09000003 1995-01-01   93284.51832
# 3              Bexley  E09000004 1995-01-01   64958.09036
# 4               Brent  E09000005 1995-01-01   71306.56698

# %%
Prop_NullFilter.count()
# Out:
# London Borough    10675
# LB ID             10675
# Date              10675
# AveragePrice      10675
# dtype: int64

# %%
Prop_NullFilter2 = Properties_Filtered[Properties_Filtered['AveragePrice']].dropna()
#Prop_NullFilter2.head(5)
#Properties_Filtered[Properties_Filtered['AveragePrice'].notna()==False]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-220-15193a350d82> in <module>
# ----> 1 Prop_NullFilter2 = Properties_Filtered[Properties_Filtered['AveragePrice']].dropna()
#       2 #Prop_NullFilter2.head(5)
#       3 #Properties_Filtered[Properties_Filtered['AveragePrice'].notna()==False]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550
#    1551         self._validate_read_indexer(
# -> 1552             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1553         )
#    1554         return keyarr, indexer
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1637             if missing == len(indexer):
#    1638                 axis_name = self.obj._get_axis_name(axis)
# -> 1639                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1640
#    1641             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Float64Index([91448.98487,  50460.2266, 93284.51832, 64958.09036, 71306.56698,\n              81671.47692, 120932.8881, 69158.16225, 79885.89069, 72514.69096,\n              ...\n              423192.8687, 664536.4638, 525472.6926, 376154.7358, 498227.8399,\n              443509.7964, 615207.1739, 937356.0042, 592328.3682, 427977.8244],\n             dtype='float64', length=10675)] are in the [columns]"

# %% [markdown]
# **2.6. Visualizing the data**
#
# To visualize the data, why not subset on a particular London Borough? Maybe do a line plot of Month against Average Price?

# %%
Bexley_Pricing = Properties_Filtered[Properties_Filtered['London Borough'] =='Bexley']
Bexley_Pricing.head(5)
# Out:
#     London Borough      LB ID       Date  AveragePrice
# 3           Bexley  E09000004 1995-01-01   64958.09036
# 51          Bexley  E09000004 1995-02-01   64787.92069
# 99          Bexley  E09000004 1995-03-01   64367.49344
# 147         Bexley  E09000004 1995-04-01   64277.66881
# 195         Bexley  E09000004 1995-05-01   63997.13588

# %%
bex = Bexley_Pricing.plot(kind='line', x='Date', y='AveragePrice').set_ylabel('Pricing')

# %% [markdown]
# To limit the number of data points you have, you might want to extract the year from every month value your *Month* column.
#
# To this end, you *could* apply a ***lambda function***. Your logic could work as follows:
# 1. look through the `Month` column
# 2. extract the year from each individual value in that column
# 3. store that corresponding year as separate column.
#
# Whether you go ahead with this is up to you. Just so long as you answer our initial brief: which boroughs of London have seen the greatest house price increase, on average, over the past two decades?

# %%
Bexley_Pricing['Year'] = Bexley_Pricing['Date'].apply(lambda y: y.year)

Bexley_Pricing.head()
# Out:
# C:\Users\abhiram.muktineni\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#     London Borough      LB ID       Date  AveragePrice  Year
# 3           Bexley  E09000004 1995-01-01   64958.09036  1995
# 51          Bexley  E09000004 1995-02-01   64787.92069  1995
# 99          Bexley  E09000004 1995-03-01   64367.49344  1995
# 147         Bexley  E09000004 1995-04-01   64277.66881  1995
# 195         Bexley  E09000004 1995-05-01   63997.13588  1995

# %%
bex_yr_mean = Bexley_Pricing.groupby(['London Borough', 'Year']).mean()
bex_yr_mean.head(10)
# Out:
#                       AveragePrice
# London Borough Year
# Bexley         1995   64291.532845
#                1996   65490.417234
#                1997   70789.406603
#                1998   80632.020822
#                1999   86777.715903
#                2000  103186.665184
#                2001  116527.134750
#                2002  136797.964475
#                2003  164482.038908
#                2004  179141.168258

# %%
bex_yr_mean = bex_yr_mean.reset_index()
bex_yr_mean.head(10)
# Out:
#   London Borough  Year   AveragePrice
# 0         Bexley  1995   64291.532845
# 1         Bexley  1996   65490.417234
# 2         Bexley  1997   70789.406603
# 3         Bexley  1998   80632.020822
# 4         Bexley  1999   86777.715903
# 5         Bexley  2000  103186.665184
# 6         Bexley  2001  116527.134750
# 7         Bexley  2002  136797.964475
# 8         Bexley  2003  164482.038908
# 9         Bexley  2004  179141.168258

# %% [markdown]
# **3. Modeling**
#
# Consider creating a function that will calculate a ratio of house prices, comparing the price of a house in 2018 to the price in 1998.
#
# Consider calling this function create_price_ratio.
#
# You'd want this function to:
# 1. Take a filter of dfg, specifically where this filter constrains the London_Borough, as an argument. For example, one admissible argument should be: dfg[dfg['London_Borough']=='Camden'].
# 2. Get the Average Price for that Borough, for the years 1998 and 2018.
# 4. Calculate the ratio of the Average Price for 1998 divided by the Average Price for 2018.
# 5. Return that ratio.
#
# Once you've written this function, you ultimately want to use it to iterate through all the unique London_Boroughs and work out the ratio capturing the difference of house prices between 1998 and 2018.
#
# Bear in mind: you don't have to write a function like this if you don't want to. If you can solve the brief otherwise, then great!
#
# ***Hint***: This section should test the skills you acquired in:
# - Python Data Science Toolbox - Part One, all modules

# %%
dfg = Properties_Filtered
dfg = dfg.dropna()
dfg = dfg[dfg['London Borough']=='Camden']

# %%
dfg['Year'] = dfg['Date'].apply(lambda y: y.year)
dfg
# Out:
#       London Borough      LB ID       Date  AveragePrice  Year
# 6             Camden  E09000007 1995-01-01   120932.8881  1995
# 54            Camden  E09000007 1995-02-01   119508.8622  1995
# 102           Camden  E09000007 1995-03-01   120282.2131  1995
# 150           Camden  E09000007 1995-04-01   120097.8990  1995
# 198           Camden  E09000007 1995-05-01   119929.2782  1995
# ...              ...        ...        ...           ...   ...
# 14406         Camden  E09000007 2020-01-01   815512.4609  2020
# 14454         Camden  E09000007 2020-02-01   825249.3994  2020
# 14502         Camden  E09000007 2020-03-01   870106.8452  2020
# 14550         Camden  E09000007 2020-04-01   870626.7601  2020
# 14598         Camden  E09000007 2020-05-01   862208.9963  2020
#
# [305 rows x 5 columns]

# %%
dfg = dfg.groupby(['London Borough', 'Year']).mean()
dfg.head(10)
# Out:
#                       AveragePrice
# London Borough Year
# Camden         1995  120367.431783
#                1996  133810.487933
#                1997  150142.901208
#                1998  170688.973933
#                1999  191090.697392
#                2000  247114.633575
#                2001  278594.043717
#                2002  314179.507833
#                2003  323053.850375
#                2004  351847.799300

# %%
dfg = dfg.reset_index()
dfg.head(10)
# Out:
#   London Borough  Year   AveragePrice
# 0         Camden  1995  120367.431783
# 1         Camden  1996  133810.487933
# 2         Camden  1997  150142.901208
# 3         Camden  1998  170688.973933
# 4         Camden  1999  191090.697392
# 5         Camden  2000  247114.633575
# 6         Camden  2001  278594.043717
# 7         Camden  2002  314179.507833
# 8         Camden  2003  323053.850375
# 9         Camden  2004  351847.799300

# %%
dfg1 = Properties_Filtered
dfg1 = dfg1.dropna()

def price_ratio(d):
    y1998 = d['AveragePrice'][d['Year'] == 1998]
    y2018 = d['AveragePrice'][d['Year'] == 2018]
    ratio = [y1998 / y2018]
    return ratio

# %%
dfg1['Year'] = dfg1['Date'].apply(lambda y: y.year)
dfg1.head()
# Out:
#        London Borough      LB ID       Date  AveragePrice  Year
# 0      City of London  E09000001 1995-01-01   91448.98487  1995
# 1  Barking & Dagenham  E09000002 1995-01-01   50460.22660  1995
# 2              Barnet  E09000003 1995-01-01   93284.51832  1995
# 3              Bexley  E09000004 1995-01-01   64958.09036  1995
# 4               Brent  E09000005 1995-01-01   71306.56698  1995

# %%
dfg1['AveragePrice'].dtypes
# Out:
# dtype('float64')

# %%
price_ratio(dfg1[dfg1['London Borough']=='Barking & Dagenham'])
#Barking & Dagenham
# Out:
# [1729    NaN
#  1777    NaN
#  1825    NaN
#  1873    NaN
#  1921    NaN
#  1969    NaN
#  2017    NaN
#  2065    NaN
#  2113    NaN
#  2161    NaN
#  2209    NaN
#  2257    NaN
#  13249   NaN
#  13297   NaN
#  13345   NaN
#  13393   NaN
#  13441   NaN
#  13489   NaN
#  13537   NaN
#  13585   NaN
#  13633   NaN
#  13681   NaN
#  13729   NaN
#  13777   NaN
#  Name: AveragePrice, dtype: float64]

# %%
final = {}

# %%
for b in dfg1['London Borough'].unique():
    # Let's make our parameter to our create_price_ratio function: i.e., we subset dfg on 'London_Borough' == b. 
    borough = dfg1[dfg1['London Borough'] == b]
    # Make a new entry in the final dictionary whose value's the result of calling create_price_ratio with the argument: borough
    final[b] = price_ratio(borough)
# We use the function and incorporate that into a new key of the dictionary 
print(final)
# Out:
# {'City of London': [1728    NaN
# 1776    NaN
# 1824    NaN
# 1872    NaN
# 1920    NaN
# 1968    NaN
# 2016    NaN
# 2064    NaN
# 2112    NaN
# 2160    NaN
# 2208    NaN
# 2256    NaN
# 13248   NaN
# 13296   NaN
# 13344   NaN
# 13392   NaN
# 13440   NaN
# 13488   NaN
# 13536   NaN
# 13584   NaN
# 13632   NaN
# 13680   NaN
# 13728   NaN
# 13776   NaN
# Name: AveragePrice, dtype: float64], 'Barking & Dagenham': [1729    NaN
# 1777    NaN
# 1825    NaN
# 1873    NaN
# 1921    NaN
# 1969    NaN
# 2017    NaN
# 2065    NaN
# 2113    NaN
# 2161    NaN
# 2209    NaN
# 2257    NaN
# 13249   NaN
# 13297   NaN
# 13345   NaN
# 13393   NaN
# 13441   NaN
# 13489   NaN
# 13537   NaN
# 13585   NaN
# 13633   NaN
# 13681   NaN
# 13729   NaN
# 13777   NaN
# Name: AveragePrice, dtype: float64], 'Barnet': [1730    NaN
# 1778    NaN
# 1826    NaN
# 1874    NaN
# 1922    NaN
# 1970    NaN
# 2018    NaN
# 2066    NaN
# 2114    NaN
# 2162    NaN
# 2210    NaN
# 2258    NaN
# 13250   NaN
# 13298   NaN
# 13346   NaN
# 13394   NaN
# 13442   NaN
# 13490   NaN
# 13538   NaN
# 13586   NaN
# 13634   NaN
# 13682   NaN
# 13730   NaN
# 13778   NaN
# Name: AveragePrice, dtype: float64], 'Bexley': [1731    NaN
# 1779    NaN
# 1827    NaN
# 1875    NaN
# 1923    NaN
# 1971    NaN
# 2019    NaN
# 2067    NaN
# 2115    NaN
# 2163    NaN
# 2211    NaN
# 2259    NaN
# 13251   NaN
# 13299   NaN
# 13347   NaN
# 13395   NaN
# 13443   NaN
# 13491   NaN
# 13539   NaN
# 13587   NaN
# 13635   NaN
# 13683   NaN
# 13731   NaN
# 13779   NaN
# Name: AveragePrice, dtype: float64], 'Brent': [1732    NaN
# 1780    NaN
# 1828    NaN
# 1876    NaN
# 1924    NaN
# 1972    NaN
# 2020    NaN
# 2068    NaN
# 2116    NaN
# 2164    NaN
# 2212    NaN
# 2260    NaN
# 13252   NaN
# 13300   NaN
# 13348   NaN
# 13396   NaN
# 13444   NaN
# 13492   NaN
# 13540   NaN
# 13588   NaN
# 13636   NaN
# 13684   NaN
# 13732   NaN
# 13780   NaN
# Name: AveragePrice, dtype: float64], 'Bromley': [1733    NaN
# 1781    NaN
# 1829    NaN
# 1877    NaN
# 1925    NaN
# 1973    NaN
# 2021    NaN
# 2069    NaN
# 2117    NaN
# 2165    NaN
# 2213    NaN
# 2261    NaN
# 13253   NaN
# 13301   NaN
# 13349   NaN
# 13397   NaN
# 13445   NaN
# 13493   NaN
# 13541   NaN
# 13589   NaN
# 13637   NaN
# 13685   NaN
# 13733   NaN
# 13781   NaN
# Name: AveragePrice, dtype: float64], 'Camden': [1734    NaN
# 1782    NaN
# 1830    NaN
# 1878    NaN
# 1926    NaN
# 1974    NaN
# 2022    NaN
# 2070    NaN
# 2118    NaN
# 2166    NaN
# 2214    NaN
# 2262    NaN
# 13254   NaN
# 13302   NaN
# 13350   NaN
# 13398   NaN
# 13446   NaN
# 13494   NaN
# 13542   NaN
# 13590   NaN
# 13638   NaN
# 13686   NaN
# 13734   NaN
# 13782   NaN
# Name: AveragePrice, dtype: float64], 'Croydon': [1735    NaN
# 1783    NaN
# 1831    NaN
# 1879    NaN
# 1927    NaN
# 1975    NaN
# 2023    NaN
# 2071    NaN
# 2119    NaN
# 2167    NaN
# 2215    NaN
# 2263    NaN
# 13255   NaN
# 13303   NaN
# 13351   NaN
# 13399   NaN
# 13447   NaN
# 13495   NaN
# 13543   NaN
# 13591   NaN
# 13639   NaN
# 13687   NaN
# 13735   NaN
# 13783   NaN
# Name: AveragePrice, dtype: float64], 'Ealing': [1736    NaN
# 1784    NaN
# 1832    NaN
# 1880    NaN
# 1928    NaN
# 1976    NaN
# 2024    NaN
# 2072    NaN
# 2120    NaN
# 2168    NaN
# 2216    NaN
# 2264    NaN
# 13256   NaN
# 13304   NaN
# 13352   NaN
# 13400   NaN
# 13448   NaN
# 13496   NaN
# 13544   NaN
# 13592   NaN
# 13640   NaN
# 13688   NaN
# 13736   NaN
# 13784   NaN
# Name: AveragePrice, dtype: float64], 'Enfield': [1737    NaN
# 1785    NaN
# 1833    NaN
# 1881    NaN
# 1929    NaN
# 1977    NaN
# 2025    NaN
# 2073    NaN
# 2121    NaN
# 2169    NaN
# 2217    NaN
# 2265    NaN
# 13257   NaN
# 13305   NaN
# 13353   NaN
# 13401   NaN
# 13449   NaN
# 13497   NaN
# 13545   NaN
# 13593   NaN
# 13641   NaN
# 13689   NaN
# 13737   NaN
# 13785   NaN
# Name: AveragePrice, dtype: float64], 'Greenwich': [1738    NaN
# 1786    NaN
# 1834    NaN
# 1882    NaN
# 1930    NaN
# 1978    NaN
# 2026    NaN
# 2074    NaN
# 2122    NaN
# 2170    NaN
# 2218    NaN
# 2266    NaN
# 13258   NaN
# 13306   NaN
# 13354   NaN
# 13402   NaN
# 13450   NaN
# 13498   NaN
# 13546   NaN
# 13594   NaN
# 13642   NaN
# 13690   NaN
# 13738   NaN
# 13786   NaN
# Name: AveragePrice, dtype: float64], 'Hackney': [1739    NaN
# 1787    NaN
# 1835    NaN
# 1883    NaN
# 1931    NaN
# 1979    NaN
# 2027    NaN
# 2075    NaN
# 2123    NaN
# 2171    NaN
# 2219    NaN
# 2267    NaN
# 13259   NaN
# 13307   NaN
# 13355   NaN
# 13403   NaN
# 13451   NaN
# 13499   NaN
# 13547   NaN
# 13595   NaN
# 13643   NaN
# 13691   NaN
# 13739   NaN
# 13787   NaN
# Name: AveragePrice, dtype: float64], 'Hammersmith & Fulham': [1740    NaN
# 1788    NaN
# 1836    NaN
# 1884    NaN
# 1932    NaN
# 1980    NaN
# 2028    NaN
# 2076    NaN
# 2124    NaN
# 2172    NaN
# 2220    NaN
# 2268    NaN
# 13260   NaN
# 13308   NaN
# 13356   NaN
# 13404   NaN
# 13452   NaN
# 13500   NaN
# 13548   NaN
# 13596   NaN
# 13644   NaN
# 13692   NaN
# 13740   NaN
# 13788   NaN
# Name: AveragePrice, dtype: float64], 'Haringey': [1741    NaN
# 1789    NaN
# 1837    NaN
# 1885    NaN
# 1933    NaN
# 1981    NaN
# 2029    NaN
# 2077    NaN
# 2125    NaN
# 2173    NaN
# 2221    NaN
# 2269    NaN
# 13261   NaN
# 13309   NaN
# 13357   NaN
# 13405   NaN
# 13453   NaN
# 13501   NaN
# 13549   NaN
# 13597   NaN
# 13645   NaN
# 13693   NaN
# 13741   NaN
# 13789   NaN
# Name: AveragePrice, dtype: float64], 'Harrow': [1742    NaN
# 1790    NaN
# 1838    NaN
# 1886    NaN
# 1934    NaN
# 1982    NaN
# 2030    NaN
# 2078    NaN
# 2126    NaN
# 2174    NaN
# 2222    NaN
# 2270    NaN
# 13262   NaN
# 13310   NaN
# 13358   NaN
# 13406   NaN
# 13454   NaN
# 13502   NaN
# 13550   NaN
# 13598   NaN
# 13646   NaN
# 13694   NaN
# 13742   NaN
# 13790   NaN
# Name: AveragePrice, dtype: float64], 'Havering': [1743    NaN
# 1791    NaN
# 1839    NaN
# 1887    NaN
# 1935    NaN
# 1983    NaN
# 2031    NaN
# 2079    NaN
# 2127    NaN
# 2175    NaN
# 2223    NaN
# 2271    NaN
# 13263   NaN
# 13311   NaN
# 13359   NaN
# 13407   NaN
# 13455   NaN
# 13503   NaN
# 13551   NaN
# 13599   NaN
# 13647   NaN
# 13695   NaN
# 13743   NaN
# 13791   NaN
# Name: AveragePrice, dtype: float64], 'Hillingdon': [1744    NaN
# 1792    NaN
# 1840    NaN
# 1888    NaN
# 1936    NaN
# 1984    NaN
# 2032    NaN
# 2080    NaN
# 2128    NaN
# 2176    NaN
# 2224    NaN
# 2272    NaN
# 13264   NaN
# 13312   NaN
# 13360   NaN
# 13408   NaN
# 13456   NaN
# 13504   NaN
# 13552   NaN
# 13600   NaN
# 13648   NaN
# 13696   NaN
# 13744   NaN
# 13792   NaN
# Name: AveragePrice, dtype: float64], 'Hounslow': [1745    NaN
# 1793    NaN
# 1841    NaN
# 1889    NaN
# 1937    NaN
# 1985    NaN
# 2033    NaN
# 2081    NaN
# 2129    NaN
# 2177    NaN
# 2225    NaN
# 2273    NaN
# 13265   NaN
# 13313   NaN
# 13361   NaN
# 13409   NaN
# 13457   NaN
# 13505   NaN
# 13553   NaN
# 13601   NaN
# 13649   NaN
# 13697   NaN
# 13745   NaN
# 13793   NaN
# Name: AveragePrice, dtype: float64], 'Islington': [1746    NaN
# 1794    NaN
# 1842    NaN
# 1890    NaN
# 1938    NaN
# 1986    NaN
# 2034    NaN
# 2082    NaN
# 2130    NaN
# 2178    NaN
# 2226    NaN
# 2274    NaN
# 13266   NaN
# 13314   NaN
# 13362   NaN
# 13410   NaN
# 13458   NaN
# 13506   NaN
# 13554   NaN
# 13602   NaN
# 13650   NaN
# 13698   NaN
# 13746   NaN
# 13794   NaN
# Name: AveragePrice, dtype: float64], 'Kensington & Chelsea': [1747    NaN
# 1795    NaN
# 1843    NaN
# 1891    NaN
# 1939    NaN
# 1987    NaN
# 2035    NaN
# 2083    NaN
# 2131    NaN
# 2179    NaN
# 2227    NaN
# 2275    NaN
# 13267   NaN
# 13315   NaN
# 13363   NaN
# 13411   NaN
# 13459   NaN
# 13507   NaN
# 13555   NaN
# 13603   NaN
# 13651   NaN
# 13699   NaN
# 13747   NaN
# 13795   NaN
# Name: AveragePrice, dtype: float64], 'Kingston upon Thames': [1748    NaN
# 1796    NaN
# 1844    NaN
# 1892    NaN
# 1940    NaN
# 1988    NaN
# 2036    NaN
# 2084    NaN
# 2132    NaN
# 2180    NaN
# 2228    NaN
# 2276    NaN
# 13268   NaN
# 13316   NaN
# 13364   NaN
# 13412   NaN
# 13460   NaN
# 13508   NaN
# 13556   NaN
# 13604   NaN
# 13652   NaN
# 13700   NaN
# 13748   NaN
# 13796   NaN
# Name: AveragePrice, dtype: float64], 'Lambeth': [1749    NaN
# 1797    NaN
# 1845    NaN
# 1893    NaN
# 1941    NaN
# 1989    NaN
# 2037    NaN
# 2085    NaN
# 2133    NaN
# 2181    NaN
# 2229    NaN
# 2277    NaN
# 13269   NaN
# 13317   NaN
# 13365   NaN
# 13413   NaN
# 13461   NaN
# 13509   NaN
# 13557   NaN
# 13605   NaN
# 13653   NaN
# 13701   NaN
# 13749   NaN
# 13797   NaN
# Name: AveragePrice, dtype: float64], 'Lewisham': [1750    NaN
# 1798    NaN
# 1846    NaN
# 1894    NaN
# 1942    NaN
# 1990    NaN
# 2038    NaN
# 2086    NaN
# 2134    NaN
# 2182    NaN
# 2230    NaN
# 2278    NaN
# 13270   NaN
# 13318   NaN
# 13366   NaN
# 13414   NaN
# 13462   NaN
# 13510   NaN
# 13558   NaN
# 13606   NaN
# 13654   NaN
# 13702   NaN
# 13750   NaN
# 13798   NaN
# Name: AveragePrice, dtype: float64], 'Merton': [1751    NaN
# 1799    NaN
# 1847    NaN
# 1895    NaN
# 1943    NaN
# 1991    NaN
# 2039    NaN
# 2087    NaN
# 2135    NaN
# 2183    NaN
# 2231    NaN
# 2279    NaN
# 13271   NaN
# 13319   NaN
# 13367   NaN
# 13415   NaN
# 13463   NaN
# 13511   NaN
# 13559   NaN
# 13607   NaN
# 13655   NaN
# 13703   NaN
# 13751   NaN
# 13799   NaN
# Name: AveragePrice, dtype: float64], 'Newham': [1752    NaN
# 1800    NaN
# 1848    NaN
# 1896    NaN
# 1944    NaN
# 1992    NaN
# 2040    NaN
# 2088    NaN
# 2136    NaN
# 2184    NaN
# 2232    NaN
# 2280    NaN
# 13272   NaN
# 13320   NaN
# 13368   NaN
# 13416   NaN
# 13464   NaN
# 13512   NaN
# 13560   NaN
# 13608   NaN
# 13656   NaN
# 13704   NaN
# 13752   NaN
# 13800   NaN
# Name: AveragePrice, dtype: float64], 'Redbridge': [1753    NaN
# 1801    NaN
# 1849    NaN
# 1897    NaN
# 1945    NaN
# 1993    NaN
# 2041    NaN
# 2089    NaN
# 2137    NaN
# 2185    NaN
# 2233    NaN
# 2281    NaN
# 13273   NaN
# 13321   NaN
# 13369   NaN
# 13417   NaN
# 13465   NaN
# 13513   NaN
# 13561   NaN
# 13609   NaN
# 13657   NaN
# 13705   NaN
# 13753   NaN
# 13801   NaN
# Name: AveragePrice, dtype: float64], 'Richmond upon Thames': [1754    NaN
# 1802    NaN
# 1850    NaN
# 1898    NaN
# 1946    NaN
# 1994    NaN
# 2042    NaN
# 2090    NaN
# 2138    NaN
# 2186    NaN
# 2234    NaN
# 2282    NaN
# 13274   NaN
# 13322   NaN
# 13370   NaN
# 13418   NaN
# 13466   NaN
# 13514   NaN
# 13562   NaN
# 13610   NaN
# 13658   NaN
# 13706   NaN
# 13754   NaN
# 13802   NaN
# Name: AveragePrice, dtype: float64], 'Southwark': [1755    NaN
# 1803    NaN
# 1851    NaN
# 1899    NaN
# 1947    NaN
# 1995    NaN
# 2043    NaN
# 2091    NaN
# 2139    NaN
# 2187    NaN
# 2235    NaN
# 2283    NaN
# 13275   NaN
# 13323   NaN
# 13371   NaN
# 13419   NaN
# 13467   NaN
# 13515   NaN
# 13563   NaN
# 13611   NaN
# 13659   NaN
# 13707   NaN
# 13755   NaN
# 13803   NaN
# Name: AveragePrice, dtype: float64], 'Sutton': [1756    NaN
# 1804    NaN
# 1852    NaN
# 1900    NaN
# 1948    NaN
# 1996    NaN
# 2044    NaN
# 2092    NaN
# 2140    NaN
# 2188    NaN
# 2236    NaN
# 2284    NaN
# 13276   NaN
# 13324   NaN
# 13372   NaN
# 13420   NaN
# 13468   NaN
# 13516   NaN
# 13564   NaN
# 13612   NaN
# 13660   NaN
# 13708   NaN
# 13756   NaN
# 13804   NaN
# Name: AveragePrice, dtype: float64], 'Tower Hamlets': [1757    NaN
# 1805    NaN
# 1853    NaN
# 1901    NaN
# 1949    NaN
# 1997    NaN
# 2045    NaN
# 2093    NaN
# 2141    NaN
# 2189    NaN
# 2237    NaN
# 2285    NaN
# 13277   NaN
# 13325   NaN
# 13373   NaN
# 13421   NaN
# 13469   NaN
# 13517   NaN
# 13565   NaN
# 13613   NaN
# 13661   NaN
# 13709   NaN
# 13757   NaN
# 13805   NaN
# Name: AveragePrice, dtype: float64], 'Waltham Forest': [1758    NaN
# 1806    NaN
# 1854    NaN
# 1902    NaN
# 1950    NaN
# 1998    NaN
# 2046    NaN
# 2094    NaN
# 2142    NaN
# 2190    NaN
# 2238    NaN
# 2286    NaN
# 13278   NaN
# 13326   NaN
# 13374   NaN
# 13422   NaN
# 13470   NaN
# 13518   NaN
# 13566   NaN
# 13614   NaN
# 13662   NaN
# 13710   NaN
# 13758   NaN
# 13806   NaN
# Name: AveragePrice, dtype: float64], 'Wandsworth': [1759    NaN
# 1807    NaN
# 1855    NaN
# 1903    NaN
# 1951    NaN
# 1999    NaN
# 2047    NaN
# 2095    NaN
# 2143    NaN
# 2191    NaN
# 2239    NaN
# 2287    NaN
# 13279   NaN
# 13327   NaN
# 13375   NaN
# 13423   NaN
# 13471   NaN
# 13519   NaN
# 13567   NaN
# 13615   NaN
# 13663   NaN
# 13711   NaN
# 13759   NaN
# 13807   NaN
# Name: AveragePrice, dtype: float64], 'Westminster': [1760    NaN
# 1808    NaN
# 1856    NaN
# 1904    NaN
# 1952    NaN
# 2000    NaN
# 2048    NaN
# 2096    NaN
# 2144    NaN
# 2192    NaN
# 2240    NaN
# 2288    NaN
# 13280   NaN
# 13328   NaN
# 13376   NaN
# 13424   NaN
# 13472   NaN
# 13520   NaN
# 13568   NaN
# 13616   NaN
# 13664   NaN
# 13712   NaN
# 13760   NaN
# 13808   NaN
# Name: AveragePrice, dtype: float64], 'Inner London': [1762    NaN
# 1810    NaN
# 1858    NaN
# 1906    NaN
# 1954    NaN
# 2002    NaN
# 2050    NaN
# 2098    NaN
# 2146    NaN
# 2194    NaN
# 2242    NaN
# 2290    NaN
# 13282   NaN
# 13330   NaN
# 13378   NaN
# 13426   NaN
# 13474   NaN
# 13522   NaN
# 13570   NaN
# 13618   NaN
# 13666   NaN
# 13714   NaN
# 13762   NaN
# 13810   NaN
# Name: AveragePrice, dtype: float64], 'Outer London': [1763    NaN
# 1811    NaN
# 1859    NaN
# 1907    NaN
# 1955    NaN
# 2003    NaN
# 2051    NaN
# 2099    NaN
# 2147    NaN
# 2195    NaN
# 2243    NaN
# 2291    NaN
# 13283   NaN
# 13331   NaN
# 13379   NaN
# 13427   NaN
# 13475   NaN
# 13523   NaN
# 13571   NaN
# 13619   NaN
# 13667   NaN
# 13715   NaN
# 13763   NaN
# 13811   NaN
# Name: AveragePrice, dtype: float64]}

# %%
df_ratios = pd.DataFrame(final)

# %%
df_ratios.head()
# Out:
#                                       City of London  \
# 0  1728    NaN
# 1776    NaN
# 1824    NaN
# 1872    Na...
#
#                                   Barking & Dagenham  \
# 0  1729    NaN
# 1777    NaN
# 1825    NaN
# 1873    Na...
#
#                                               Barnet  \
# 0  1730    NaN
# 1778    NaN
# 1826    NaN
# 1874    Na...
#
#                                               Bexley  \
# 0  1731    NaN
# 1779    NaN
# 1827    NaN
# 1875    Na...
#
#                                                Brent  \
# 0  1732    NaN
# 1780    NaN
# 1828    NaN
# 1876    Na...
#
#                                              Bromley  \
# 0  1733    NaN
# 1781    NaN
# 1829    NaN
# 1877    Na...
#
#                                               Camden  \
# 0  1734    NaN
# 1782    NaN
# 1830    NaN
# 1878    Na...
#
#                                              Croydon  \
# 0  1735    NaN
# 1783    NaN
# 1831    NaN
# 1879    Na...
#
#                                               Ealing  \
# 0  1736    NaN
# 1784    NaN
# 1832    NaN
# 1880    Na...
#
#                                              Enfield  ...  \
# 0  1737    NaN
# 1785    NaN
# 1833    NaN
# 1881    Na...  ...
#
#                                            Redbridge  \
# 0  1753    NaN
# 1801    NaN
# 1849    NaN
# 1897    Na...
#
#                                 Richmond upon Thames  \
# 0  1754    NaN
# 1802    NaN
# 1850    NaN
# 1898    Na...
#
#                                            Southwark  \
# 0  1755    NaN
# 1803    NaN
# 1851    NaN
# 1899    Na...
#
#                                               Sutton  \
# 0  1756    NaN
# 1804    NaN
# 1852    NaN
# 1900    Na...
#
#                                        Tower Hamlets  \
# 0  1757    NaN
# 1805    NaN
# 1853    NaN
# 1901    Na...
#
#                                       Waltham Forest  \
# 0  1758    NaN
# 1806    NaN
# 1854    NaN
# 1902    Na...
#
#                                           Wandsworth  \
# 0  1759    NaN
# 1807    NaN
# 1855    NaN
# 1903    Na...
#
#                                          Westminster  \
# 0  1760    NaN
# 1808    NaN
# 1856    NaN
# 1904    Na...
#
#                                         Inner London  \
# 0  1762    NaN
# 1810    NaN
# 1858    NaN
# 1906    Na...
#
#                                         Outer London
# 0  1763    NaN
# 1811    NaN
# 1859    NaN
# 1907    Na...
#
# [1 rows x 35 columns]

# %% [markdown]
# ### 4. Conclusion
# What can you conclude? Type out your conclusion below.
#
# Look back at your notebook. Think about how you might summarize what you have done, and prepare a quick presentation on it to your mentor at your next meeting.
#
# We hope you enjoyed this practical project. It should have consolidated your data hygiene and pandas skills by looking at a real-world problem involving just the kind of dataset you might encounter as a budding data scientist. Congratulations, and looking forward to seeing you at the next step in the course!
